# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# 2. Đọc file csv và gắng index với giá Price
df = pd.read_csv('/content/HPG Historical Data.csv', sep=";")
df1=df.reset_index()['Price']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
print(train_data.shape, test_data.shape)
# Out:
# (1126, 1) (126, 1)

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape
time_step = 15
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, features, time steps] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0],1 ,X_test.shape[1])

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(ytest.shape)
# Out:
# (1110, 1, 15)
# (1110,)
# (110, 1, 15)
# (110,)

# %%
# 8. Define LSTM Model

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(1,15)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 18s 123ms/step - loss: 0.2147 - val_loss: 4.3793e-04
# Epoch 2/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0644 - val_loss: 0.0259
# Epoch 3/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0134 - val_loss: 0.0121
# Epoch 4/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0117
# Epoch 5/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0041 - val_loss: 0.0071
# Epoch 6/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0043
# Epoch 7/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 8/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 9/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 10/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 11/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 12/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 9.5735e-04
# Epoch 13/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 7.5631e-04
# Epoch 14/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 6.9596e-04
# Epoch 15/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 5.3596e-04
# Epoch 16/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 4.8173e-04
# Epoch 17/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 3.6100e-04
# Epoch 18/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 3.3545e-04
# Epoch 19/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 2.7347e-04
# Epoch 20/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 2.7217e-04
# Epoch 21/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 2.2505e-04
# Epoch 22/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 1.7034e-04
# Epoch 23/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 1.3426e-04
# Epoch 24/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 1.2588e-04
# Epoch 25/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 1.1854e-04
# Epoch 26/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 1.1359e-04
# Epoch 27/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 1.0962e-04
# Epoch 28/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 1.0381e-04
# Epoch 29/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 1.0211e-04
# Epoch 30/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 1.0174e-04
# Epoch 31/100
# 18/18 [==============================] - 0s 12ms/step - loss: 9.9052e-04 - val_loss: 9.8559e-05
# Epoch 32/100
# 18/18 [==============================] - 0s 14ms/step - loss: 9.5556e-04 - val_loss: 1.0011e-04
# Epoch 33/100
# 18/18 [==============================] - 0s 16ms/step - loss: 9.5790e-04 - val_loss: 9.6521e-05
# Epoch 34/100
# 18/18 [==============================] - 0s 19ms/step - loss: 9.2650e-04 - val_loss: 9.4799e-05
# Epoch 35/100
# 18/18 [==============================] - 0s 17ms/step - loss: 9.1422e-04 - val_loss: 9.7024e-05
# Epoch 36/100
# 18/18 [==============================] - 0s 16ms/step - loss: 8.8686e-04 - val_loss: 9.6484e-05
# Epoch 37/100
# 18/18 [==============================] - 0s 19ms/step - loss: 8.8441e-04 - val_loss: 9.3736e-05
# Epoch 38/100
# 18/18 [==============================] - 0s 16ms/step - loss: 8.6412e-04 - val_loss: 9.0006e-05
# Epoch 39/100
# 18/18 [==============================] - 0s 11ms/step - loss: 8.5783e-04 - val_loss: 1.0013e-04
# Epoch 40/100
# 18/18 [==============================] - 0s 12ms/step - loss: 8.4084e-04 - val_loss: 8.7843e-05
# Epoch 41/100
# 18/18 [==============================] - 0s 11ms/step - loss: 7.8514e-04 - val_loss: 9.2092e-05
# Epoch 42/100
# 18/18 [==============================] - 0s 11ms/step - loss: 7.7144e-04 - val_loss: 8.4295e-05
# Epoch 43/100
# 18/18 [==============================] - 0s 10ms/step - loss: 7.3881e-04 - val_loss: 8.5630e-05
# Epoch 44/100
# 18/18 [==============================] - 0s 11ms/step - loss: 7.0010e-04 - val_loss: 8.1533e-05
# Epoch 45/100
# 18/18 [==============================] - 0s 12ms/step - loss: 6.7792e-04 - val_loss: 8.2254e-05
# Epoch 46/100
# 18/18 [==============================] - 0s 11ms/step - loss: 6.5857e-04 - val_loss: 7.8857e-05
# Epoch 47/100
# 18/18 [==============================] - 0s 11ms/step - loss: 6.3807e-04 - val_loss: 7.7945e-05
# Epoch 48/100
# 18/18 [==============================] - 0s 11ms/step - loss: 6.0485e-04 - val_loss: 7.4052e-05
# Epoch 49/100
# 18/18 [==============================] - 0s 11ms/step - loss: 5.8048e-04 - val_loss: 7.5697e-05
# Epoch 50/100
# 18/18 [==============================] - 0s 12ms/step - loss: 5.4745e-04 - val_loss: 7.2714e-05
# Epoch 51/100
# 18/18 [==============================] - 0s 11ms/step - loss: 5.3305e-04 - val_loss: 7.1141e-05
# Epoch 52/100
# 18/18 [==============================] - 0s 10ms/step - loss: 5.0541e-04 - val_loss: 6.8977e-05
# Epoch 53/100
# 18/18 [==============================] - 0s 12ms/step - loss: 4.9600e-04 - val_loss: 6.8284e-05
# Epoch 54/100
# 18/18 [==============================] - 0s 10ms/step - loss: 4.7954e-04 - val_loss: 6.9174e-05
# Epoch 55/100
# 18/18 [==============================] - 0s 14ms/step - loss: 4.7153e-04 - val_loss: 6.6135e-05
# Epoch 56/100
# 18/18 [==============================] - 0s 11ms/step - loss: 5.0481e-04 - val_loss: 6.3795e-05
# Epoch 57/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.8965e-04 - val_loss: 6.3278e-05
# Epoch 58/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.4515e-04 - val_loss: 6.3576e-05
# Epoch 59/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.6557e-04 - val_loss: 6.1772e-05
# Epoch 60/100
# 18/18 [==============================] - 0s 14ms/step - loss: 4.5255e-04 - val_loss: 6.1720e-05
# Epoch 61/100
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4013e-04 - val_loss: 6.0226e-05
# Epoch 62/100
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3053e-04 - val_loss: 5.9254e-05
# Epoch 63/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.5988e-04 - val_loss: 5.9041e-05
# Epoch 64/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.3609e-04 - val_loss: 6.3328e-05
# Epoch 65/100
# 18/18 [==============================] - 0s 14ms/step - loss: 4.1370e-04 - val_loss: 6.0627e-05
# Epoch 66/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1450e-04 - val_loss: 5.7982e-05
# Epoch 67/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.0974e-04 - val_loss: 6.1720e-05
# Epoch 68/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1514e-04 - val_loss: 5.7587e-05
# Epoch 69/100
# 18/18 [==============================] - 0s 12ms/step - loss: 4.5483e-04 - val_loss: 5.8164e-05
# Epoch 70/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.5224e-04 - val_loss: 5.6857e-05
# Epoch 71/100
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0653e-04 - val_loss: 5.5027e-05
# Epoch 72/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1970e-04 - val_loss: 5.5061e-05
# Epoch 73/100
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9913e-04 - val_loss: 5.9714e-05
# Epoch 74/100
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0739e-04 - val_loss: 5.4833e-05
# Epoch 75/100
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8079e-04 - val_loss: 5.3711e-05
# Epoch 76/100
# 18/18 [==============================] - 0s 9ms/step - loss: 3.9389e-04 - val_loss: 5.3325e-05
# Epoch 77/100
# 18/18 [==============================] - 0s 9ms/step - loss: 3.9145e-04 - val_loss: 5.3366e-05
# Epoch 78/100
# 18/18 [==============================] - 0s 9ms/step - loss: 4.5466e-04 - val_loss: 5.3006e-05
# Epoch 79/100
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2779e-04 - val_loss: 5.4571e-05
# Epoch 80/100
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8782e-04 - val_loss: 5.3192e-05
# Epoch 81/100
# 18/18 [==============================] - 0s 9ms/step - loss: 3.8442e-04 - val_loss: 5.6783e-05
# Epoch 82/100
# 18/18 [==============================] - 0s 9ms/step - loss: 3.7737e-04 - val_loss: 5.1892e-05
# Epoch 83/100
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7590e-04 - val_loss: 5.3096e-05
# Epoch 84/100
# 18/18 [==============================] - 0s 9ms/step - loss: 4.0850e-04 - val_loss: 5.1044e-05
# Epoch 85/100
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7006e-04 - val_loss: 5.1838e-05
# Epoch 86/100
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7358e-04 - val_loss: 5.7960e-05
# Epoch 87/100
# 18/18 [==============================] - 0s 9ms/step - loss: 3.5481e-04 - val_loss: 4.9508e-05
# Epoch 88/100
# 18/18 [==============================] - 0s 9ms/step - loss: 3.5827e-04 - val_loss: 5.1552e-05
# Epoch 89/100
# 18/18 [==============================] - 0s 12ms/step - loss: 3.7242e-04 - val_loss: 5.1701e-05
# Epoch 90/100
# 18/18 [==============================] - 0s 14ms/step - loss: 3.7318e-04 - val_loss: 4.8587e-05
# Epoch 91/100
# 18/18 [==============================] - 0s 15ms/step - loss: 3.8784e-04 - val_loss: 4.8286e-05
# Epoch 92/100
# 18/18 [==============================] - 0s 15ms/step - loss: 3.9263e-04 - val_loss: 4.8185e-05
# Epoch 93/100
# 18/18 [==============================] - 0s 13ms/step - loss: 3.5897e-04 - val_loss: 4.8676e-05
# Epoch 94/100
# 18/18 [==============================] - 0s 15ms/step - loss: 3.7158e-04 - val_loss: 4.9683e-05
# Epoch 95/100
# 18/18 [==============================] - 0s 17ms/step - loss: 4.0274e-04 - val_loss: 4.8008e-05
# Epoch 96/100
# 18/18 [==============================] - 0s 17ms/step - loss: 3.6151e-04 - val_loss: 4.7661e-05
# Epoch 97/100
# 18/18 [==============================] - 0s 15ms/step - loss: 3.8583e-04 - val_loss: 5.5994e-05
# Epoch 98/100
# 18/18 [==============================] - 0s 18ms/step - loss: 3.9109e-04 - val_loss: 4.6922e-05
# Epoch 99/100
# 18/18 [==============================] - 0s 17ms/step - loss: 3.5289e-04 - val_loss: 4.6402e-05
# Epoch 100/100
# 18/18 [==============================] - 0s 16ms/step - loss: 3.3627e-04 - val_loss: 4.8531e-05

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
# Out:
# 35/35 [==============================] - 1s 3ms/step
# 4/4 [==============================] - 0s 4ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
print('Testing RMSE:', test_rmse)
# Out:
# Testing RMSE: 10.816527125195073

# %%
# Chuyển đổi dữ liệu kiểm tra thành danh sách
x_input = test_data[60:].reshape(1, -1)
temp_input = list(x_input[0])

from numpy import array

lst_output = []
n_steps = 15
i = 0

while i < 30:
    if len(temp_input) > 100:
        # Chuẩn bị dữ liệu đầu vào mới
        x_input = np.array(temp_input[-15:])  # Lấy đúng 100 phần tử cuối cùng
        print("{} day input {}".format(i, x_input))

        x_input = x_input.reshape((1, 1, n_steps))

        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i, yhat))

        # Thêm giá trị dự đoán vào danh sách tạm thời
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input[-n_steps:]).reshape((1, 1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])

        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))

        lst_output.extend(yhat.tolist())
        i += 1
# Out:
# [0.12811725]
# 67
# [0.12694359]
# 68
# [0.12609869]
# 69
# [0.12597975]
# 70
# [0.12526129]
# 71
# [0.12460616]
# 72
# [0.12361643]
# 73
# [0.12288379]
# 74
# [0.12212779]
# 75
# [0.12136227]
# 76
# [0.1208338]
# 77
# [0.1199864]
# 78
# [0.11917237]
# 79
# [0.11836909]
# 80
# [0.11781064]
# 81
# [0.11712977]
# 82
# [0.11648512]
# 83
# [0.11586402]
# 84
# [0.11523193]
# 85
# [0.11462231]
# 86
# [0.11401722]
# 87
# [0.11343393]
# 88
# [0.11286232]
# 89
# [0.11230721]
# 90
# [0.11176416]
# 91
# [0.11122371]
# 92
# [0.11070231]
# 93
# [0.11019457]
# 94
# [0.10969852]
# 95
# [0.10921042]
# 96

# %%
# 14.Vẽ hình
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+16, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))

plt.legend(['Train','Test','Predict','Predict30days'])
plt.show()

# %%
# Chuyển đổi dữ liệu kiểm tra thành danh sách
x_input = test_data[60:].reshape(1, -1)
temp_input = list(x_input[0])

from numpy import array

lst_output = []
n_steps = 15
i = 0

while i < 60:
    if len(temp_input) > 15:
        # Chuẩn bị dữ liệu đầu vào mới
        x_input = np.array(temp_input[-15:])  # Lấy đúng 100 phần tử cuối cùng
        print("{} day input {}".format(i, x_input))

        x_input = x_input.reshape((1, 1, n_steps))

        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i, yhat))

        # Thêm giá trị dự đoán vào danh sách tạm thời
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])

        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))

        lst_output.extend(yhat.tolist())
        i += 1
# Out:
# 0 day input [0.10552571 0.10843109 0.10456639 0.10407302 0.10456639 0.12674049
#  0.12819318 0.12336915 0.12290319 0.12432847 0.12578116 0.1344699
#  0.13493586 0.13784125 0.12723386]
# 0 day output [[0.12811725]]
# 1 day input [0.10843109 0.10456639 0.10407302 0.10456639 0.12674049 0.12819318
#  0.12336915 0.12290319 0.12432847 0.12578116 0.1344699  0.13493586
#  0.13784125 0.12723386 0.12811725]
# 1 day output [[0.12694359]]
# 2 day input [0.10456639 0.10407302 0.10456639 0.12674049 0.12819318 0.12336915
#  0.12290319 0.12432847 0.12578116 0.1344699  0.13493586 0.13784125
#  0.12723386 0.12811725 0.12694359]
# 2 day output [[0.12609869]]
# 3 day input [0.10407302 0.10456639 0.12674049 0.12819318 0.12336915 0.12290319
#  0.12432847 0.12578116 0.1344699  0.13493586 0.13784125 0.12723386
#  0.12811725 0.12694359 0.12609869]
# 3 day output [[0.12597975]]
# 4 day input [0.10456639 0.12674049 0.12819318 0.12336915 0.12290319 0.12432847
#  0.12578116 0.1344699  0.13493586 0.13784125 0.12723386 0.12811725
#  0.12694359 0.12609869 0.12597975]
# 4 day output [[0.12526129]]
# 5 day input [0.12674049 0.12819318 0.12336915 0.12290319 0.12432847 0.12578116
#  0.1344699  0.13493586 0.13784125 0.12723386 0.12811725 0.12694359
#  0.12609869 0.12597975 0.12526129]
# 5 day output [[0.12460616]]
# 6 day input [0.12819318 0.12336915 0.12290319 0.12432847 0.12578116 0.1344699
#  0.13493586 0.13784125 0.12723386 0.12811725 0.12694359 0.12609869
#  0.12597975 0.12526129 0.12460616]
# 6 day output [[0.12361643]]
# 7 day input [0.12336915 0.12290319 0.12432847 0.12578116 0.1344699  0.13493586
#  0.13784125 0.12723386 0.12811725 0.12694359 0.12609869 0.12597975
#  0.12526129 0.12460616 0.12361643]
# 7 day output [[0.12288379]]
# 8 day input [0.12290319 0.12432847 0.12578116 0.1344699  0.13493586 0.13784125
#  0.12723386 0.12811725 0.12694359 0.12609869 0.12597975 0.12526129
#  0.12460616 0.12361643 0.12288379]
# 8 day output [[0.12212779]]
# 9 day input [0.12432847 0.12578116 0.1344699  0.13493586 0.13784125 0.12723386
#  0.12811725 0.12694359 0.12609869 0.12597975 0.12526129 0.12460616
#  0.12361643 0.12288379 0.12212779]
# 9 day output [[0.12136227]]
# 10 day input [0.12578116 0.1344699  0.13493586 0.13784125 0.12723386 0.12811725
#  0.12694359 0.12609869 0.12597975 0.12526129 0.12460616 0.12361643
#  0.12288379 0.12212779 0.12136227]
# 10 day output [[0.1208338]]
# 11 day input [0.1344699  0.13493586 0.13784125 0.12723386 0.12811725 0.12694359
#  0.12609869 0.12597975 0.12526129 0.12460616 0.12361643 0.12288379
#  0.12212779 0.12136227 0.1208338 ]
# 11 day output [[0.1199864]]
# 12 day input [0.13493586 0.13784125 0.12723386 0.12811725 0.12694359 0.12609869
#  0.12597975 0.12526129 0.12460616 0.12361643 0.12288379 0.12212779
#  0.12136227 0.1208338  0.1199864 ]
# 12 day output [[0.11917237]]
# 13 day input [0.13784125 0.12723386 0.12811725 0.12694359 0.12609869 0.12597975
#  0.12526129 0.12460616 0.12361643 0.12288379 0.12212779 0.12136227
#  0.1208338  0.1199864  0.11917237]
# 13 day output [[0.11836909]]
# 14 day input [0.12723386 0.12811725 0.12694359 0.12609869 0.12597975 0.12526129
#  0.12460616 0.12361643 0.12288379 0.12212779 0.12136227 0.1208338
#  0.1199864  0.11917237 0.11836909]
# 14 day output [[0.11781064]]
# 15 day input [0.12811725 0.12694359 0.12609869 0.12597975 0.12526129 0.12460616
#  0.12361643 0.12288379 0.12212779 0.12136227 0.1208338  0.1199864
#  0.11917237 0.11836909 0.11781064]
# 15 day output [[0.11712977]]
# 16 day input [0.12694359 0.12609869 0.12597975 0.12526129 0.12460616 0.12361643
#  0.12288379 0.12212779 0.12136227 0.1208338  0.1199864  0.11917237
#  0.11836909 0.11781064 0.11712977]
# 16 day output [[0.11648512]]
# 17 day input [0.12609869 0.12597975 0.12526129 0.12460616 0.12361643 0.12288379
#  0.12212779 0.12136227 0.1208338  0.1199864  0.11917237 0.11836909
#  0.11781064 0.11712977 0.11648512]
# 17 day output [[0.11586402]]
# 18 day input [0.12597975 0.12526129 0.12460616 0.12361643 0.12288379 0.12212779
#  0.12136227 0.1208338  0.1199864  0.11917237 0.11836909 0.11781064
#  0.11712977 0.11648512 0.11586402]
# 18 day output [[0.11523193]]
# 19 day input [0.12526129 0.12460616 0.12361643 0.12288379 0.12212779 0.12136227
#  0.1208338  0.1199864  0.11917237 0.11836909 0.11781064 0.11712977
#  0.11648512 0.11586402 0.11523193]
# 19 day output [[0.11462231]]
# 20 day input [0.12460616 0.12361643 0.12288379 0.12212779 0.12136227 0.1208338
#  0.1199864  0.11917237 0.11836909 0.11781064 0.11712977 0.11648512
#  0.11586402 0.11523193 0.11462231]
# 20 day output [[0.11401722]]
# 21 day input [0.12361643 0.12288379 0.12212779 0.12136227 0.1208338  0.1199864
#  0.11917237 0.11836909 0.11781064 0.11712977 0.11648512 0.11586402
#  0.11523193 0.11462231 0.11401722]
# 21 day output [[0.11343393]]
# 22 day input [0.12288379 0.12212779 0.12136227 0.1208338  0.1199864  0.11917237
#  0.11836909 0.11781064 0.11712977 0.11648512 0.11586402 0.11523193
#  0.11462231 0.11401722 0.11343393]
# 22 day output [[0.11286232]]
# 23 day input [0.12212779 0.12136227 0.1208338  0.1199864  0.11917237 0.11836909
#  0.11781064 0.11712977 0.11648512 0.11586402 0.11523193 0.11462231
#  0.11401722 0.11343393 0.11286232]
# 23 day output [[0.11230721]]
# 24 day input [0.12136227 0.1208338  0.1199864  0.11917237 0.11836909 0.11781064
#  0.11712977 0.11648512 0.11586402 0.11523193 0.11462231 0.11401722
#  0.11343393 0.11286232 0.11230721]
# 24 day output [[0.11176416]]
# 25 day input [0.1208338  0.1199864  0.11917237 0.11836909 0.11781064 0.11712977
#  0.11648512 0.11586402 0.11523193 0.11462231 0.11401722 0.11343393
#  0.11286232 0.11230721 0.11176416]
# 25 day output [[0.11122371]]
# 26 day input [0.1199864  0.11917237 0.11836909 0.11781064 0.11712977 0.11648
# 53 day output [[0.10037213]]
# 54 day input [0.10491533 0.10453862 0.10417058 0.10381105 0.10345992 0.10311703
#  0.1027822  0.10245516 0.10213585 0.10182405 0.10151961 0.10122234
#  0.10093212 0.10064877 0.10037213]
# 54 day output [[0.10010204]]
# 55 day input [0.10453862 0.10417058 0.10381105 0.10345992 0.10311703 0.1027822
#  0.10245516 0.10213585 0.10182405 0.10151961 0.10122234 0.10093212
#  0.10064877 0.10037213 0.10010204]
# 55 day output [[0.09983839]]
# 56 day input [0.10417058 0.10381105 0.10345992 0.10311703 0.1027822  0.10245516
#  0.10213585 0.10182405 0.10151961 0.10122234 0.10093212 0.10064877
#  0.10037213 0.10010204 0.09983839]
# 56 day output [[0.099581]]
# 57 day input [0.10381105 0.10345992 0.10311703 0.1027822  0.10245516 0.10213585
#  0.10182405 0.10151961 0.10122234 0.10093212 0.10064877 0.10037213
#  0.10010204 0.09983839 0.099581  ]
# 57 day output [[0.09932974]]
# 58 day input [0.10345992 0.10311703 0.1027822  0.10245516 0.10213585 0.10182405
#  0.10151961 0.10122234 0.10093212 0.10064877 0.10037213 0.10010204
#  0.09983839 0.099581   0.09932974]
# 58 day output [[0.0990845]]
# 59 day input [0.10311703 0.1027822  0.10245516 0.10213585 0.10182405 0.10151961
#  0.10122234 0.10093212 0.10064877 0.10037213 0.10010204 0.09983839
#  0.099581   0.09932974 0.0990845 ]
# 59 day output [[0.09884509]]

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(train_data_index, scaler.inverse_transform(train_data), label='Train')

test_data_index = pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data), label='Test')

pred_data_index = pd.RangeIndex(start=train_size + 16, stop=train_size + test_size, step=1)
plt.plot(pred_data_index, y_pred, label='Predict')

predict_data_index = pd.RangeIndex(start=len(df1) - 1, stop=len(df1) + 59, step=1)

lst_output_flat = np.array(lst_output).reshape(-1)
plt.plot(predict_data_index, scaler.inverse_transform(lst_output_flat.reshape(-1, 1)), label='Predict60days')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-3fd74f698f98> in <cell line: 13>()
#      11
#      12 lst_output_flat = np.array(lst_output).reshape(-1)
# ---> 13 plt.plot(predict_data_index, scaler.inverse_transform(lst_output_flat.reshape(-1, 1)), label='Predict60days')
#      14
#      15 plt.legend()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (60,) and (90, 1)

# %%
# Chuyển đổi dữ liệu kiểm tra thành danh sách
x_input = test_data[60:].reshape(1, -1)
temp_input = list(x_input[0])

from numpy import array

lst_output = []
n_steps = 15
i = 0

while i < 90:
    if len(temp_input) > 15:
        # Chuẩn bị dữ liệu đầu vào mới
        x_input = np.array(temp_input[-15:])  # Lấy đúng 100 phần tử cuối cùng
        print("{} day input {}".format(i, x_input))

        x_input = x_input.reshape((1,1, n_steps))

        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i, yhat))

        # Thêm giá trị dự đoán vào danh sách tạm thời
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1,1 ,n_steps))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])

        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))

        lst_output.extend(yhat.tolist())
        i += 1
# Out:
# 0 day input [0.10552571 0.10843109 0.10456639 0.10407302 0.10456639 0.12674049
#  0.12819318 0.12336915 0.12290319 0.12432847 0.12578116 0.1344699
#  0.13493586 0.13784125 0.12723386]
# 0 day output [[0.12811725]]
# 1 day input [0.10843109 0.10456639 0.10407302 0.10456639 0.12674049 0.12819318
#  0.12336915 0.12290319 0.12432847 0.12578116 0.1344699  0.13493586
#  0.13784125 0.12723386 0.12811725]
# 1 day output [[0.12694359]]
# 2 day input [0.10456639 0.10407302 0.10456639 0.12674049 0.12819318 0.12336915
#  0.12290319 0.12432847 0.12578116 0.1344699  0.13493586 0.13784125
#  0.12723386 0.12811725 0.12694359]
# 2 day output [[0.12609869]]
# 3 day input [0.10407302 0.10456639 0.12674049 0.12819318 0.12336915 0.12290319
#  0.12432847 0.12578116 0.1344699  0.13493586 0.13784125 0.12723386
#  0.12811725 0.12694359 0.12609869]
# 3 day output [[0.12597975]]
# 4 day input [0.10456639 0.12674049 0.12819318 0.12336915 0.12290319 0.12432847
#  0.12578116 0.1344699  0.13493586 0.13784125 0.12723386 0.12811725
#  0.12694359 0.12609869 0.12597975]
# 4 day output [[0.12526129]]
# 5 day input [0.12674049 0.12819318 0.12336915 0.12290319 0.12432847 0.12578116
#  0.1344699  0.13493586 0.13784125 0.12723386 0.12811725 0.12694359
#  0.12609869 0.12597975 0.12526129]
# 5 day output [[0.12460616]]
# 6 day input [0.12819318 0.12336915 0.12290319 0.12432847 0.12578116 0.1344699
#  0.13493586 0.13784125 0.12723386 0.12811725 0.12694359 0.12609869
#  0.12597975 0.12526129 0.12460616]
# 6 day output [[0.12361643]]
# 7 day input [0.12336915 0.12290319 0.12432847 0.12578116 0.1344699  0.13493586
#  0.13784125 0.12723386 0.12811725 0.12694359 0.12609869 0.12597975
#  0.12526129 0.12460616 0.12361643]
# 7 day output [[0.12288379]]
# 8 day input [0.12290319 0.12432847 0.12578116 0.1344699  0.13493586 0.13784125
#  0.12723386 0.12811725 0.12694359 0.12609869 0.12597975 0.12526129
#  0.12460616 0.12361643 0.12288379]
# 8 day output [[0.12212779]]
# 9 day input [0.12432847 0.12578116 0.1344699  0.13493586 0.13784125 0.12723386
#  0.12811725 0.12694359 0.12609869 0.12597975 0.12526129 0.12460616
#  0.12361643 0.12288379 0.12212779]
# 9 day output [[0.12136227]]
# 10 day input [0.12578116 0.1344699  0.13493586 0.13784125 0.12723386 0.12811725
#  0.12694359 0.12609869 0.12597975 0.12526129 0.12460616 0.12361643
#  0.12288379 0.12212779 0.12136227]
# 10 day output [[0.1208338]]
# 11 day input [0.1344699  0.13493586 0.13784125 0.12723386 0.12811725 0.12694359
#  0.12609869 0.12597975 0.12526129 0.12460616 0.12361643 0.12288379
#  0.12212779 0.12136227 0.1208338 ]
# 11 day output [[0.1199864]]
# 12 day input [0.13493586 0.13784125 0.12723386 0.12811725 0.12694359 0.12609869
#  0.12597975 0.12526129 0.12460616 0.12361643 0.12288379 0.12212779
#  0.12136227 0.1208338  0.1199864 ]
# 12 day output [[0.11917237]]
# 13 day input [0.13784125 0.12723386 0.12811725 0.12694359 0.12609869 0.12597975
#  0.12526129 0.12460616 0.12361643 0.12288379 0.12212779 0.12136227
#  0.1208338  0.1199864  0.11917237]
# 13 day output [[0.11836909]]
# 14 day input [0.12723386 0.12811725 0.12694359 0.12609869 0.12597975 0.12526129
#  0.12460616 0.12361643 0.12288379 0.12212779 0.12136227 0.1208338
#  0.1199864  0.11917237 0.11836909]
# 14 day output [[0.11781064]]
# 15 day input [0.12811725 0.12694359 0.12609869 0.12597975 0.12526129 0.12460616
#  0.12361643 0.12288379 0.12212779 0.12136227 0.1208338  0.1199864
#  0.11917237 0.11836909 0.11781064]
# 15 day output [[0.11712977]]
# 16 day input [0.12694359 0.12609869 0.12597975 0.12526129 0.12460616 0.12361643
#  0.12288379 0.12212779 0.12136227 0.1208338  0.1199864  0.11917237
#  0.11836909 0.11781064 0.11712977]
# 16 day output [[0.11648512]]
# 17 day input [0.12609869 0.12597975 0.12526129 0.12460616 0.12361643 0.12288379
#  0.12212779 0.12136227 0.1208338  0.1199864  0.11917237 0.11836909
#  0.11781064 0.11712977 0.11648512]
# 17 day output [[0.11586402]]
# 18 day input [0.12597975 0.12526129 0.12460616 0.12361643 0.12288379 0.12212779
#  0.12136227 0.1208338  0.1199864  0.11917237 0.11836909 0.11781064
#  0.11712977 0.11648512 0.11586402]
# 18 day output [[0.11523193]]
# 19 day input [0.12526129 0.12460616 0.12361643 0.12288379 0.12212779 0.12136227
#  0.1208338  0.1199864  0.11917237 0.11836909 0.11781064 0.11712977
#  0.11648512 0.11586402 0.11523193]
# 19 day output [[0.11462231]]
# 20 day input [0.12460616 0.12361643 0.12288379 0.12212779 0.12136227 0.1208338
#  0.1199864  0.11917237 0.11836909 0.11781064 0.11712977 0.11648512
#  0.11586402 0.11523193 0.11462231]
# 20 day output [[0.11401722]]
# 21 day input [0.12361643 0.12288379 0.12212779 0.12136227 0.1208338  0.1199864
#  0.11917237 0.11836909 0.11781064 0.11712977 0.11648512 0.11586402
#  0.11523193 0.11462231 0.11401722]
# 21 day output [[0.11343393]]
# 22 day input [0.12288379 0.12212779 0.12136227 0.1208338  0.1199864  0.11917237
#  0.11836909 0.11781064 0.11712977 0.11648512 0.11586402 0.11523193
#  0.11462231 0.11401722 0.11343393]
# 22 day output [[0.11286232]]
# 23 day input [0.12212779 0.12136227 0.1208338  0.1199864  0.11917237 0.11836909
#  0.11781064 0.11712977 0.11648512 0.11586402 0.11523193 0.11462231
#  0.11401722 0.11343393 0.11286232]
# 23 day output [[0.11230721]]
# 24 day input [0.12136227 0.1208338  0.1199864  0.11917237 0.11836909 0.11781064
#  0.11712977 0.11648512 0.11586402 0.11523193 0.11462231 0.11401722
#  0.11343393 0.11286232 0.11230721]
# 24 day output [[0.11176416]]
# 25 day input [0.1208338  0.1199864  0.11917237 0.11836909 0.11781064 0.11712977
#  0.11648512 0.11586402 0.11523193 0.11462231 0.11401722 0.11343393
#  0.11286232 0.11230721 0.11176416]
# 25 day output [[0.11122371]]
# 26 day input [0.1199864  0.11917237 0.11836909 0.11781064 0.11712977 0.11648512
#  0.11586402 0.11523193 0.11462231 0.11401722 0.11343393 0.11286232
#  0.11230721 0.11176416 0.11122371]
# 26 day output [[0.11070231]]
# 27 day input [0.11917237 0.11836909 0.11781064 0.11712977 0.11648512 0.11586402
#  0.11523193 0.11462231 0.11401722 0.11343393 0.11286232 0.11230721
#  0.11176416 0.11122371 0.11070231]
# 27 day output [[0.11019457]]
# 28 day input [0.11836909 0.11781064 0.11712977 0.11648512 0.11586402 0.11523193
#  0.11462231 0.11401722 0.11343393 0.11286232 0.11230721 0.11176416
#  0.11122371 0.11070231 0.11019457]
# 28 day output [[0.10969852]]
# 29 day input [0.11781064 0.11712977 0.11648512 0.11586402 0.11523193 0.11462231
#  0.11401722 0.11343393 0.11286232 0.11230721 0.11176416 0.11122371
#  0.11070231 0.11019457 0.10969852]
# 29 day output [[0.10921042]]
# 30 day input [0.11712977 0.11648512 0.11586402 0.11523193 0.11462231 0.11401722
#  0.11343393 0.11286232 0.11230721 0.11176416 0.11122371 0.11070231
#  0.11019457 0.10969852 0.10921042]
# 30 day output [[0.10873491]]
# 31 day input [0.11648512 0.11586402 0.11523193 0.11462231 0.11401722 0.11343393
#  0.11286232 0.11230721 0.11176416 0.11122371 0.11070231 0.11019457
#  0.10969852 0.10921042 0.10873491]
# 31 day output [[0.10827029]]
# 32 day input [0.11586402 0.11523193 0.11462231 0.11401722 0.11343393 0.11286232
#  0.11230721 0.11176416 0.11122371 0.11070231 0.11019457 0.10969852
#  0.10921042 0.10873491 0.10827029]
# 32 day output [[0.10781566]]
# 33 day input [0.11523193 0.11462231 0.11401722 0.11343393 0.11286232 0.11230721
#  0.11176416 0.11122371 0.11070231 0.11019457 0.10969852 0.10921042
#  0.10873491 0.10827029 0.10781566]
# 33 day output [[0.10737183]]
# 34 day input [0.11462231 0.11401722 0.11343393 0.11286232 0.11230721 0.11176416
#  0.11122371 0.11070231 0.11019457 0.10969852 0.10921042 0.10873491
#  0.10827029 0.10781566 0.10737183]
# 34 day output [[0.10693798]]
# 35 day input [0.11401722 0.11343393 0.11286232 0.11230721 0.11176416 0.11122371
#  0.11070231 0.11019457 0.10969852 0.10921042 0.10873491 0.10827029
#  0.10781566 0.10737183 0.10693798]
# 35 day output [[0.10651441]]
# 36 day input [0.11343393 0.11286232 0.11230721 0.11176416 0.11122371 0.11070231
#  0.11019457 0.10969852 0.10921042 0.10873491 0.10827029 0.10781566
#  0.10737183 0.10693798 0.10651441]
# 36 day output [[0.10610063]]
# 37 day input [0.11286232 0.11230721 0.11176416 0.11122371 0.11070231 0.11019457
#  0.10969852 0.10921042 0.10873491 0.10827029 0.10781566 0.10737183
#  0.10693798 0.10651441 0.10610063]
# 37 day output [[0.10569637]]
# 38 day input [0.11230721 0.11176416 0.11122371 0.11070231 0.11019457 0.10969852
#  0.10921042 0.10873491 0.10827029 0.10781566 0.10737183 0.10693798
#  0.10651441 0.10610063 0.10569637]
# 38 day output [[0.10530128]]
# 39 day input [0.11176416 0.11122371 0.11070231 0.11019457 0.10969852 0.10921042
#  0.10873491 0.10827029 0.10781566 0.10737183 0.10693798 0.10651441
#  0.10610063 0.10569637 0.10530128]
# 39 day output [[0.10491533]]
# 40 day input [0.11122371 0.11070231 0.11019457 0.10969852 0.10921042 0.10873491
#  0.10122234 0.10093212 0.10064877]
# 53 day output [[0.10037213]]
# 54 day input [0.10491533 0.10453862 0.10417058 0.10381105 0.10345992 0.10311703
#  0.1027822  0.10245516 0.10213585 0.10182405 0.10151961 0.10122234
#  0.10093212 0.10064877 0.10037213]
# 54 day output [[0.10010204]]
# 55 day input [0.10453862 0.10417058 0.10381105 0.10345992 0.10311703 0.1027822
#  0.10245516 0.10213585 0.10182405 0.10151961 0.10122234 0.10093212
#  0.10064877 0.10037213 0.10010204]
# 55 day output [[0.09983839]]
# 56 day input [0.10417058 0.10381105 0.10345992 0.10311703 0.1027822  0.10245516
#  0.10213585 0.10182405 0.10151961 0.10122234 0.10093212 0.10064877
#  0.10037213 0.10010204 0.09983839]
# 56 day output [[0.099581]]
# 57 day input [0.10381105 0.10345992 0.10311703 0.1027822  0.10245516 0.10213585
#  0.10182405 0.10151961 0.10122234 0.10093212 0.10064877 0.10037213
#  0.10010204 0.09983839 0.099581  ]
# 57 day output [[0.09932974]]
# 58 day input [0.10345992 0.10311703 0.1027822  0.10245516 0.10213585 0.10182405
#  0.10151961 0.10122234 0.10093212 0.10064877 0.10037213 0.10010204
#  0.09983839 0.099581   0.09932974]
# 58 day output [[0.0990845]]
# 59 day input [0.10311703 0.1027822  0.10245516 0.10213585 0.10182405 0.10151961
#  0.10122234 0.10093212 0.10064877 0.10037213 0.10010204 0.09983839
#  0.099581   0.09932974 0.0990845 ]
# 59 day output [[0.09884509]]
# 60 day input [0.1027822  0.10245516 0.10213585 0.10182405 0.10151961 0.10122234
#  0.10093212 0.10064877 0.10037213 0.10010204 0.09983839 0.099581
#  0.09932974 0.0990845  0.09884509]
# 60 day output [[0.09861142]]
# 61 day input [0.10245516 0.10213585 0.10182405 0.10151961 0.10122234 0.10093212
#  0.10064877 0.10037213 0.10010204 0.09983839 0.099581   0.09932974
#  0.0990845  0.09884509 0.09861142]
# 61 day output [[0.09838335]]
# 62 day input [0.10213585 0.10182405 0.10151961 0.10122234 0.10093212 0.10064877
#  0.10037213 0.10010204 0.09983839 0.099581   0.09932974 0.0990845
#  0.09884509 0.09861142 0.09838335]
# 62 day output [[0.09816074]]
# 63 day input [0.10182405 0.10151961 0.10122234 0.10093212 0.10064877 0.10037213
#  0.10010204 0.09983839 0.099581   0.09932974 0.0990845  0.09884509
#  0.09861142 0.09838335 0.09816074]
# 63 day output [[0.09794345]]
# 64 day input [0.10151961 0.10122234 0.10093212 0.10064877 0.10037213 0.10010204
#  0.09983839 0.099581   0.09932974 0.0990845  0.09884509 0.09861142
#  0.09838335 0.09816074 0.09794345]
# 64 day output [[0.09773138]]
# 65 day input [0.10122234 0.10093212 0.10064877 0.10037213 0.10010204 0.09983839
#  0.099581   0.09932974 0.0990845  0.09884509 0.09861142 0.09838335
#  0.09816074 0.09794345 0.09773138]
# 65 day output [[0.09752442]]
# 66 day input [0.10093212 0.10064877 0.10037213 0.10010204 0.09983839 0.099581
#  0.09932974 0.0990845  0.09884509 0.09861142 0.09838335 0.09816074
#  0.09794345 0.09773138 0.09752442]
# 66 day output [[0.09732243]]
#  0.09638327 0.09620883 0.0960386  0.09587251 0.09571043 0.0955523
#  0.095398   0.09524744 0.09510056]
# 80 day output [[0.09495726]]
# 81 day input [0.09732243 0.09712531 0.09693295 0.09674524 0.09656204 0.09638327
#  0.09620883 0.0960386  0.09587251 0.09571043 0.0955523  0.095398
#  0.09524744 0.09510056 0.09495726]
# 81 day output [[0.09481742]]
# 82 day input [0.09712531 0.09693295 0.09674524 0.09656204 0.09638327 0.09620883
#  0.0960386  0.09587251 0.09571043 0.0955523  0.095398   0.09524744
#  0.09510056 0.09495726 0.09481742]
# 82 day output [[0.09468099]]
# 83 day input [0.09693295 0.09674524 0.09656204 0.09638327 0.09620883 0.0960386
#  0.09587251 0.09571043 0.0955523  0.095398   0.09524744 0.09510056
#  0.09495726 0.09481742 0.09468099]
# 83 day output [[0.09454793]]
# 84 day input [0.09674524 0.09656204 0.09638327 0.09620883 0.0960386  0.09587251
#  0.09571043 0.0955523  0.095398   0.09524744 0.09510056 0.09495726
#  0.09481742 0.09468099 0.09454793]
# 84 day output [[0.09441807]]
# 85 day input [0.09656204 0.09638327 0.09620883 0.0960386  0.09587251 0.09571043
#  0.0955523  0.095398   0.09524744 0.09510056 0.09495726 0.09481742
#  0.09468099 0.09454793 0.09441807]
# 85 day output [[0.09429139]]
# 86 day input [0.09638327 0.09620883 0.0960386  0.09587251 0.09571043 0.0955523
#  0.095398   0.09524744 0.09510056 0.09495726 0.09481742 0.09468099
#  0.09454793 0.09441807 0.09429139]
# 86 day output [[0.0941678]]
# 87 day input [0.09620883 0.0960386  0.09587251 0.09571043 0.0955523  0.095398
#  0.09524744 0.09510056 0.09495726 0.09481742 0.09468099 0.09454793
#  0.09441807 0.09429139 0.0941678 ]
# 87 day output [[0.09404725]]
# 88 day input [0.0960386  0.09587251 0.09571043 0.0955523  0.095398   0.09524744
#  0.09510056 0.09495726 0.09481742 0.09468099 0.09454793 0.09441807
#  0.09429139 0.0941678  0.09404725]
# 88 day output [[0.09392963]]
# 89 day input [0.09587251 0.09571043 0.0955523  0.095398   0.09524744 0.09510056
#  0.09495726 0.09481742 0.09468099 0.09454793 0.09441807 0.09429139
#  0.0941678  0.09404725 0.09392963]
# 89 day output [[0.09381491]]

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(train_data_index, scaler.inverse_transform(train_data), label='Train')

# Chỉ số cho dữ liệu kiểm tra
test_data_index = pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data), label='Test')

# Chỉ số cho dữ liệu dự đoán
pred_data_index = pd.RangeIndex(start=train_size + 16, stop=train_size + test_size, step=1)
plt.plot(pred_data_index, y_pred, label='Predict')

# Chỉ số cho dữ liệu dự báo 90 ngày
predict_data_index = pd.RangeIndex(start=len(df1) - 1, stop=len(df1) + 89, step=1)

# Chuyển đổi lst_output thành dạng phù hợp
lst_output_flat = np.array(lst_output).reshape(-1)
plt.plot(predict_data_index, scaler.inverse_transform(lst_output_flat.reshape(-1, 1)), label='Predict90days')

# Hiển thị đồ thị
plt.legend()
plt.show()
